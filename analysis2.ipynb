# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from termcolor import colored

# %%
def read_file(file):
    data= np.loadtxt('QEEG_data/'+file+'.csv', skiprows=1, delimiter=',', unpack= True, usecols=(1,2,3,4))
    return data

# %%
channel= np.loadtxt('QEEG_data/A1/A11.csv', skiprows=1, delimiter=',', unpack= True, usecols=(0), dtype= 'str')

# %%
# no: 第幾次做的EEG
# cha：頻道
# fre: 頻率的index
def ch_data(chan, freq, no, mask):
    ch= np.array([])
    for i in range(1,6):
        filepath= str(mask)+str(i)+'/'+str(mask)+str(i)+str(no)
        A_ch1= read_file(filepath)[freq][chan]
        ch= np.append(ch, A_ch1)
    return ch

print('第一次')

def Wilcoxon_ch(freq, no1, no2, mask):
    p_value_w= np.array([])
    p_value_p= np.array([])
    for i in range(0, 19):
        print('Channel:', channel[i])
        A_0to4_ch1_1= ch_data(i,freq,no1, mask)
        A_0to4_ch1_2= ch_data(i,freq,no2, mask)
        print('Wilcoxon')
        a= stats.wilcoxon(A_0to4_ch1_1, A_0to4_ch1_2)
        print(a)
        print('Paired T-test')
        b= stats.ttest_rel(A_0to4_ch1_1, A_0to4_ch1_2)
        print(b)
        print('')
        p_value_w= np.append(p_value_w, a[1])
        p_value_p= np.append(p_value_p, b[1])
    return p_value_w,  p_value_p


print('面膜A 前和中比較')
print('Frequency: 0-4 Hz')
print('')
A_delta_12= Wilcoxon_ch(0, 1, 2, 'A')
print('')

        
print('面膜A 前和中比較')
print('Frequency: 4-8 Hz')
print('')
A_theta_12= Wilcoxon_ch(1, 1, 2, 'A')


print('面膜A 前和中比較')
print('Frequency: 8-13 Hz')
print('')
A_alpha_12= Wilcoxon_ch(2, 1, 2, 'A')


print('面膜A 前和中比較')
print('Frequency: 13-30 Hz')
print('')
A_beta_12= Wilcoxon_ch(3, 1, 2, 'A')
# Out:
# 第一次
# 面膜A 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=1.7892911783847654, pvalue=0.14807280544236465, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=1.4598667081606302, pvalue=0.21810388990335713, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
# Paired T-test
# TtestResult(statistic=0.9369025928653384, pvalue=0.40185159040980345, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
# Paired T-test
# TtestResult(statistic=0.6103955476066579, pvalue=0.5745781546747306, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.5228770579161821, pvalue=0.6286852398837476, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# ...

# %%
print('面膜A 中和後比較')
print('Frequency: 0-4 Hz')
print('')
A_delta_23= Wilcoxon_ch(0, 2, 3, 'A')
print('')

        
print('面膜A 中和後比較')
print('Frequency: 4-8 Hz')
print('')
A_theta_23= Wilcoxon_ch(1, 2, 3, 'A')


print('面膜A 中和後比較')
print('Frequency: 8-13 Hz')
print('')
A_alpha_23= Wilcoxon_ch(2, 2, 3, 'A')


print('面膜A 中和後比較')
print('Frequency: 13-30 Hz')
print('')
A_beta_23= Wilcoxon_ch(3, 2, 3, 'A')
# Out:
# 面膜A 中和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=-1.1170210632903674, pvalue=0.32654938069610384, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.5, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=-1.046989068202892, pvalue=0.3541982394834664, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
# Paired T-test
# TtestResult(statistic=-0.9513350910701714, pvalue=0.39530553525154, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=7.0, pvalue=1.0)
# Paired T-test
# TtestResult(statistic=-0.3549710883038288, pvalue=0.7405368120045424, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=-0.8301606065938687, pvalue=0.45312176821598477, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.5, pvalue=0.8539232992870668)
# ...

# %%
print('面膜A 前和後比較')
print('Frequency: 0-4 Hz')
print('')
A_delta_13= Wilcoxon_ch(0, 1, 3, 'A')
print('')

        
print('面膜A 前和後比較')
print('Frequency: 4-8 Hz')
print('')
A_theta_13= Wilcoxon_ch(1, 1, 3, 'A')


print('面膜A 前和後比較')
print('Frequency: 8-13 Hz')
print('')
A_alpha_13= Wilcoxon_ch(2, 1, 3, 'A')


print('面膜A 前和後比較')
print('Frequency: 13-30 Hz')
print('')
A_beta_13= Wilcoxon_ch(3, 1, 3, 'A')
# Out:
# 面膜A 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=7.0, pvalue=1.0)
# Paired T-test
# TtestResult(statistic=0.1316473415239714, pvalue=0.9016193768549098, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
# Paired T-test
# TtestResult(statistic=-0.15931324696929144, pvalue=0.881142678192515, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
# Paired T-test
# TtestResult(statistic=-0.8431077656631778, pvalue=0.4466331651672024, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
# Paired T-test
# TtestResult(statistic=0.3880062835970842, pvalue=0.7177757456473064, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
# Paired T-test
# TtestResult(statistic=-1.2395096191736494, pvalue=0.28291009734838113, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=7.0, pvalue=1.0)
# Paired T-test
# ...

# %%
def P_value(List):
    for i in range(4):
        print(title[i])
        index_w= np.where(List[i][0] < 0.1)
        if len(index_w[0])!=0:
            print('Wilcoxon: p-value 小於 0.1')
            print(channel[index_w])
       
        index_p= np.where(List[i][1] < 0.1)
        if len(index_p[0])!=0:
            print('Paired T test: p-value 小於 0.1')
            print(channel[index_p])
        print('')
        

List_A12= [A_delta_12, A_theta_12, A_alpha_12, A_beta_12]
List_A23= [A_delta_23, A_theta_23, A_alpha_23, A_beta_23]
List_A13= [A_delta_13, A_theta_13, A_alpha_13, A_beta_13]

title= ['Delta', 'Theta', 'Alpha', 'Beta']

print('A面膜第一次前中比較')
P_value(List_A12)

print('A面膜第一次中後比較')
P_value(List_A23)

print('A面膜第一次前後比較')
P_value(List_A13)
# Out:
# A面膜第一次前中比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['Fp1-A1A2' 'F3-A1A2' 'Fz-A1A2' 'Fp2-A1A2' 'O2-A1A2' 'T6-A1A2']
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['Fp1-A1A2' 'F3-A1A2' 'Fp2-A1A2' 'O2-A1A2']
#
# Alpha
# Wilcoxon: p-value 小於 0.1
# ['Fp2-A1A2']
#
# Beta
# Wilcoxon: p-value 小於 0.1
# ['Fp2-A1A2' 'O2-A1A2']
#
# A面膜第一次中後比較
# Delta
#
# Theta
#
# Alpha
#
# Beta
# Wilcoxon: p-value 小於 0.1
# ['O1-A1A2' 'F4-A1A2' 'O2-A1A2']
# Paired T test: p-value 小於 0.1
# ['O1-A1A2']
#
# A面膜第一次前後比較
# Delta
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['F3-A1A2']
# Paired T test: p-value 小於 0.1
# ['F3-A1A2']
#
# Alpha
# Wilcoxon: p-value 小於 0.1
# ['P3-A1A2' 'Cz-A1A2']
# Paired T test: p-value 小於 0.1
# ['Cz-A1A2' 'C4-A1A2']
#
# Beta

# %%
print('面膜C 前和中比較')
print('Frequency: 0-4 Hz')
print('')
C_delta_12= Wilcoxon_ch(0, 1, 2, 'C')
print('')

        
print('面膜C 前和中比較')
print('Frequency: 4-8 Hz')
print('')
C_theta_12= Wilcoxon_ch(1, 1, 2, 'C')


print('面膜C 前和中比較')
print('Frequency: 8-13 Hz')
print('')
C_alpha_12= Wilcoxon_ch(2, 1, 2, 'C')


print('面膜C 前和中比較')
print('Frequency: 13-30 Hz')
print('')
C_beta_12= Wilcoxon_ch(3, 1, 2, 'C')
# Out:
# 面膜C 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=-0.6499874767004932, pvalue=0.5511423442290578, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=-0.940179348344265, pvalue=0.40035737008406097, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=1.0)
# Paired T-test
# TtestResult(statistic=0.15161960871578084, pvalue=0.886826637796094, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
# Paired T-test
# TtestResult(statistic=-1.6990563418645621, pvalue=0.16453679854849534, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=-2.4654599845943137, pvalue=0.06928371235159807, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# ...

# %%
print('面膜C 中和後比較')
print('Frequency: 0-4 Hz')
print('')
C_delta_23= Wilcoxon_ch(0, 2, 3, 'C')
print('')

        
print('面膜C 中和後比較')
print('Frequency: 4-8 Hz')
print('')
C_theta_23= Wilcoxon_ch(1, 2, 3, 'C')


print('面膜C 中和後比較')
print('Frequency: 8-13 Hz')
print('')
C_alpha_23= Wilcoxon_ch(2, 2, 3, 'C')


print('面膜C 中和後比較')
print('Frequency: 13-30 Hz')
print('')
C_beta_23= Wilcoxon_ch(3, 2, 3, 'C')
# Out:
# 面膜C 中和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=1.0, pvalue=0.125)
# Paired T-test
# TtestResult(statistic=-1.5347762424510716, pvalue=0.19962963239656628, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=-0.071479240776952, pvalue=0.9464475566745285, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
# Paired T-test
# TtestResult(statistic=-1.7056057308448838, pvalue=0.16327898574659305, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=-0.21712922914182065, pvalue=0.8387329962447152, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.6170911188367963, pvalue=0.5705682291770207, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
# ...

# %%
print('面膜C 前和後比較')
print('Frequency: 0-4 Hz')
print('')
C_delta_13= Wilcoxon_ch(0, 1, 3, 'C')
print('')

        
print('面膜C 前和後比較')
print('Frequency: 4-8 Hz')
print('')
C_theta_13= Wilcoxon_ch(1, 1, 3, 'C')


print('面膜C 前和後比較')
print('Frequency: 8-13 Hz')
print('')
C_alpha_13= Wilcoxon_ch(2, 1, 3, 'C')


print('面膜C 前和後比較')
print('Frequency: 13-30 Hz')
print('')
C_beta_13= Wilcoxon_ch(3, 1, 3, 'C')
# Out:
# 面膜C 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)
# Paired T-test
# TtestResult(statistic=-1.1906320761817024, pvalue=0.29962555507258126, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=1.0, pvalue=0.125)
# Paired T-test
# TtestResult(statistic=-1.4400455531818714, pvalue=0.22327521196712857, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
# Paired T-test
# TtestResult(statistic=-1.7204749383834228, pvalue=0.1604608252776018, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=-1.212899262123937, pvalue=0.2918980314917824, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
# Paired T-test
# TtestResult(statistic=-0.4330127018922194, pvalue=0.6873318687910392, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
# ...

# %%
List_C12= [C_delta_12, C_theta_12, C_alpha_12, C_beta_12]
List_C23= [C_delta_23, C_theta_23, C_alpha_23, C_beta_23]
List_C13= [C_delta_13, C_theta_13, C_alpha_13, C_beta_13]

title= ['Delta', 'Theta', 'Alpha', 'Beta']

print('C面膜第一次前中比較')
P_value(List_C12)

print('C面膜第一次中後比較')
P_value(List_C23)

print('C面膜第一次前後比較')
P_value(List_C13)
# Out:
# C面膜第一次前中比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['O1-A1A2']
# Paired T test: p-value 小於 0.1
# ['O1-A1A2']
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['O1-A1A2' 'T5-A1A2']
# Paired T test: p-value 小於 0.1
# ['O1-A1A2' 'T5-A1A2']
#
# Alpha
# Wilcoxon: p-value 小於 0.1
# ['F7-A1A2']
# Paired T test: p-value 小於 0.1
# ['P3-A1A2']
#
# Beta
#
# C面膜第一次中後比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['T3-A1A2']
# Paired T test: p-value 小於 0.1
# ['T3-A1A2']
#
# Theta
# Paired T test: p-value 小於 0.1
# ['T3-A1A2']
#
# Alpha
#
# Beta
#
# C面膜第一次前後比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['Fp1-A1A2']
# Paired T test: p-value 小於 0.1
# ['T3-A1A2']
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['F3-A1A2' 'C4-A1A2']
#
# Alpha
#
# Beta
# Wilcoxon: p-value 小於 0.1
# ['C3-A1A2' 'F4-A1A2' 'F8-A1A2']
# Paired T test: p-value 小於 0.1
# ['F3-A1A2' 'C3-A1A2' 'F4-A1A2' 'F8-A1A2']

# %%
print('第二次')
print('')
print('面膜A 前和中比較')
print('Frequency: 0-4 Hz')
print('')
A_delta_45= Wilcoxon_ch(0, 4, 5, 'A')
print('')

        
print('面膜A 前和中比較')
print('Frequency: 4-8 Hz')
print('')
A_theta_45= Wilcoxon_ch(1, 4, 5, 'A')


print('面膜A 前和中比較')
print('Frequency: 8-13 Hz')
print('')
A_alpha_45= Wilcoxon_ch(2, 4, 5, 'A')


print('面膜A 前和中比較')
print('Frequency: 13-30 Hz')
print('')
A_beta_45= Wilcoxon_ch(3, 4, 5, 'A')
# Out:
# 第二次
#
# 面膜A 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=1.7690865229314137, pvalue=0.1516010222168724, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=1.5643304987647457, pvalue=0.19278717402516835, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=2.5467159527622236, pvalue=0.06352634787496968, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
# Paired T-test
# TtestResult(statistic=-3.7987343171876967e-16, pvalue=0.9999999999999998, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.5, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=1.119045980671216, pvalue=0.3257798595575151, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
# ...

# %%
print('面膜A 中和後比較')
print('Frequency: 0-4 Hz')
print('')
A_delta_56= Wilcoxon_ch(0, 5, 6, 'A')
print('')

        
print('面膜A 中和後比較')
print('Frequency: 4-8 Hz')
print('')
A_theta_56= Wilcoxon_ch(1, 5, 6, 'A')


print('面膜A 中和後比較')
print('Frequency: 8-13 Hz')
print('')
A_alpha_56= Wilcoxon_ch(2, 5, 6, 'A')


print('面膜A 中和後比較')
print('Frequency: 13-30 Hz')
print('')
A_beta_56= Wilcoxon_ch(3, 5, 6, 'A')
# Out:
# 面膜A 中和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=7.0, pvalue=1.0)
# Paired T-test
# TtestResult(statistic=-0.2312486450314403, pvalue=0.8284690004305417, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=1.0809899749038825, pvalue=0.3405215616600304, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=-0.8380385593601785, pvalue=0.44916474417893865, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
# Paired T-test
# TtestResult(statistic=0.4730441936401531, pvalue=0.6608398717259533, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.5292973096694772, pvalue=0.6246116841476852, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# ...

# %%
print('面膜A 前和後比較')
print('Frequency: 0-4 Hz')
print('')
A_delta_46= Wilcoxon_ch(0, 4, 6, 'A')
print('')

        
print('面膜A 前和後比較')
print('Frequency: 4-8 Hz')
print('')
A_theta_46= Wilcoxon_ch(1, 4, 6, 'A')


print('面膜A 前和後比較')
print('Frequency: 8-13 Hz')
print('')
A_alpha_46= Wilcoxon_ch(2, 4, 6, 'A')


print('面膜A 前和後比較')
print('Frequency: 13-30 Hz')
print('')
A_beta_46= Wilcoxon_ch(3, 4, 6, 'A')
# Out:
# 面膜A 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)
# Paired T-test
# TtestResult(statistic=1.6314795331058778, pvalue=0.17812466392490522, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=2.3491138903978683, pvalue=0.07859138889645197, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
# Paired T-test
# TtestResult(statistic=1.0701990476407142, pvalue=0.3448099948595494, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.3728392938105355, pvalue=0.728183773779874, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.0, pvalue=0.27332167829229814)
# Paired T-test
# TtestResult(statistic=1.181634468780189, pvalue=0.3028021812654973, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# ...

# %%
List_A45= [A_delta_45, A_theta_45, A_alpha_45, A_beta_45]
List_A56= [A_delta_56, A_theta_56, A_alpha_56, A_beta_56]
List_A46= [A_delta_46, A_theta_46, A_alpha_46, A_beta_46]

title= ['Delta', 'Theta', 'Alpha', 'Beta']

print('A面膜第二次前中比較')
P_value(List_A12)

print('A面膜第二次中後比較')
P_value(List_A23)

print('A面膜第二次前後比較')
P_value(List_A13)
# Out:
# A面膜第二次前中比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['Fp1-A1A2' 'F3-A1A2' 'Fz-A1A2' 'Fp2-A1A2' 'O2-A1A2' 'T6-A1A2']
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['Fp1-A1A2' 'F3-A1A2' 'Fp2-A1A2' 'O2-A1A2']
#
# Alpha
# Wilcoxon: p-value 小於 0.1
# ['Fp2-A1A2']
#
# Beta
# Wilcoxon: p-value 小於 0.1
# ['Fp2-A1A2' 'O2-A1A2']
#
# A面膜第二次中後比較
# Delta
#
# Theta
#
# Alpha
#
# Beta
# Wilcoxon: p-value 小於 0.1
# ['O1-A1A2' 'F4-A1A2' 'O2-A1A2']
# Paired T test: p-value 小於 0.1
# ['O1-A1A2']
#
# A面膜第二次前後比較
# Delta
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['F3-A1A2']
# Paired T test: p-value 小於 0.1
# ['F3-A1A2']
#
# Alpha
# Wilcoxon: p-value 小於 0.1
# ['P3-A1A2' 'Cz-A1A2']
# Paired T test: p-value 小於 0.1
# ['Cz-A1A2' 'C4-A1A2']
#
# Beta

# %%
print('面膜C 前和中比較')
print('Frequency: 0-4 Hz')
print('')
C_delta_45= Wilcoxon_ch(0, 4, 5, 'C')
print('')

        
print('面膜C 前和中比較')
print('Frequency: 4-8 Hz')
print('')
C_theta_45= Wilcoxon_ch(1, 4, 5, 'C')


print('面膜C 前和中比較')
print('Frequency: 8-13 Hz')
print('')
C_alpha_45= Wilcoxon_ch(2, 4, 5, 'C')


print('面膜C 前和中比較')
print('Frequency: 13-30 Hz')
print('')
C_beta_45= Wilcoxon_ch(3, 4, 5, 'C')
# Out:
# 面膜C 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
# Paired T-test
# TtestResult(statistic=1.635878254396896, pvalue=0.17720548183940416, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.5, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=1.2175985386128025, pvalue=0.29029138831593454, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.5, pvalue=0.8125)
# Paired T-test
# TtestResult(statistic=0.5511782546095503, pvalue=0.6108504002950288, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# TtestResult(statistic=4.046719640600775, pvalue=0.01551766394553458, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.0, pvalue=0.5929800980174267)
# Paired T-test
# TtestResult(statistic=0.9036519915598479, pvalue=0.41728112739407175, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=1.0, pvalue=0.125)
# ...

# %%
print('面膜C 中和後比較')
print('Frequency: 0-4 Hz')
print('')
C_delta_56= Wilcoxon_ch(0, 5, 6, 'C')
print('')

        
print('面膜C 中和後比較')
print('Frequency: 4-8 Hz')
print('')
C_theta_56= Wilcoxon_ch(1, 5, 6, 'C')


print('面膜C 中和後比較')
print('Frequency: 8-13 Hz')
print('')
C_alpha_56= Wilcoxon_ch(2, 5, 6, 'C')


print('面膜C 中和後比較')
print('Frequency: 13-30 Hz')
print('')
C_beta_56= Wilcoxon_ch(3, 5, 6, 'C')
# Out:
# 面膜C 中和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
# Paired T-test
# TtestResult(statistic=-0.6591436694831782, pvalue=0.5458176489376193, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=7.0, pvalue=1.0)
# Paired T-test
# TtestResult(statistic=-0.6948083337796509, pvalue=0.5254228339114922, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.10880943004054568)
# Paired T-test
# TtestResult(statistic=-1.5727141989855695, pvalue=0.19089036663397432, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.0, pvalue=0.5929800980174267)
# Paired T-test
# TtestResult(statistic=0.6391933293392665, pvalue=0.557465732316345, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.5, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.6785511437439767, pvalue=0.5346509952551977, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# ...

# %%
print('面膜C 前和後比較')
print('Frequency: 0-4 Hz')
print('')
C_delta_46= Wilcoxon_ch(0, 4, 6, 'C')
print('')

        
print('面膜C 前和後比較')
print('Frequency: 4-8 Hz')
print('')
C_theta_46= Wilcoxon_ch(1, 4, 6, 'C')


print('面膜C 前和後比較')
print('Frequency: 8-13 Hz')
print('')
C_alpha_46= Wilcoxon_ch(2, 4, 6, 'C')


print('面膜C 前和後比較')
print('Frequency: 13-30 Hz')
print('')
C_beta_46= Wilcoxon_ch(3, 4, 6, 'C')
# Out:
# 面膜C 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
# Paired T-test
# TtestResult(statistic=1.259101069420251, pvalue=0.27646176040137993, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.5205106400782012, pvalue=0.6301907465963901, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.5, pvalue=0.3572725590318747)
# Paired T-test
# TtestResult(statistic=-0.772667409286256, pvalue=0.48283849543969204, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=1.0292774808490002, pvalue=0.3615146728363519, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.5, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=1.0439717478968535, pvalue=0.355435303872781, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# ...

# %%
List_C45= [C_delta_45, C_theta_45, C_alpha_45, C_beta_45]
List_C56= [C_delta_56, C_theta_56, C_alpha_56, C_beta_56]
List_C46= [C_delta_46, C_theta_46, C_alpha_46, C_beta_46]

title= ['Delta', 'Theta', 'Alpha', 'Beta']

print('C面膜第二次前中比較')
P_value(List_C12)

print('C面膜第二次中後比較')
P_value(List_C23)

print('C面膜第二次前後比較')
P_value(List_C13)
# Out:
# C面膜第二次前中比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['O1-A1A2']
# Paired T test: p-value 小於 0.1
# ['O1-A1A2']
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['O1-A1A2' 'T5-A1A2']
# Paired T test: p-value 小於 0.1
# ['O1-A1A2' 'T5-A1A2']
#
# Alpha
# Wilcoxon: p-value 小於 0.1
# ['F7-A1A2']
# Paired T test: p-value 小於 0.1
# ['P3-A1A2']
#
# Beta
#
# C面膜第二次中後比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['T3-A1A2']
# Paired T test: p-value 小於 0.1
# ['T3-A1A2']
#
# Theta
# Paired T test: p-value 小於 0.1
# ['T3-A1A2']
#
# Alpha
#
# Beta
#
# C面膜第二次前後比較
# Delta
# Wilcoxon: p-value 小於 0.1
# ['Fp1-A1A2']
# Paired T test: p-value 小於 0.1
# ['T3-A1A2']
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['F3-A1A2' 'C4-A1A2']
#
# Alpha
#
# Beta
# Wilcoxon: p-value 小於 0.1
# ['C3-A1A2' 'F4-A1A2' 'F8-A1A2']
# Paired T test: p-value 小於 0.1
# ['F3-A1A2' 'C3-A1A2' 'F4-A1A2' 'F8-A1A2']

# %%
print('A面膜 第一次前和第二次後')
print('Frequency: 0-4 Hz')
print('')
A_delta_16= Wilcoxon_ch(0, 1, 6, 'A')
print('')

print('A面膜 第一次前和第二次後')
print('Frequency: 4-8 Hz')
print('')
A_theta_16= Wilcoxon_ch(1, 1, 6, 'A')


print('A面膜 第一次前和第二次後')
print('Frequency: 8-13 Hz')
print('')
A_alpha_16= Wilcoxon_ch(2, 1, 6, 'A')


print('A面膜 第一次前和第二次後')
print('Frequency: 13-30 Hz')
print('')
A_beta_16= Wilcoxon_ch(3, 1, 6, 'A')
# Out:
# A面膜 第一次前和第二次後
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
# Paired T-test
# TtestResult(statistic=1.3517956734787375, pvalue=0.24782470672734036, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=6.5, pvalue=1.0)
# Paired T-test
# TtestResult(statistic=0.06223467040124494, pvalue=0.9533616221456909, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=0.6154470619441813, pvalue=0.5715510977296583, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=-0.3058215121524218, pvalue=0.7749959682500295, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=2.5, pvalue=0.3125)
# Paired T-test
# TtestResult(statistic=1.4380282286450723, pvalue=0.22380838407678788, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# ...

# %%
print('C面膜 第一次前和第二次後')
print('Frequency: 0-4 Hz')
print('')
C_delta_16= Wilcoxon_ch(0, 1, 6, 'C')
print('')

print('C面膜 第一次前和第二次後')
print('Frequency: 4-8 Hz')
print('')
C_theta_16= Wilcoxon_ch(1, 1, 6, 'C')


print('C面膜 第一次前和第二次後')
print('Frequency: 8-13 Hz')
print('')
C_alpha_16= Wilcoxon_ch(2, 1, 6, 'C')


print('C面膜 第一次前和第二次後')
print('Frequency: 13-30 Hz')
print('')
C_beta_16= Wilcoxon_ch(3, 1, 6, 'C')
# Out:
# C面膜 第一次前和第二次後
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.6641802999107298, pvalue=0.5429040304230479, df=4)
#
# Channel: F3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=5.0, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=0.9320996355910581, pvalue=0.4040502799678446, df=4)
#
# Channel: C3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
# Paired T-test
# TtestResult(statistic=0.6058518227366905, pvalue=0.5773100597874856, df=4)
#
# Channel: P3-A1A2
# Wilcoxon
# WilcoxonResult(statistic=4.5, pvalue=0.625)
# Paired T-test
# TtestResult(statistic=1.0602186898993928, pvalue=0.3488193726584504, df=4)
#
# Channel: O1-A1A2
# Wilcoxon
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
# Paired T-test
# TtestResult(statistic=1.2255430108515966, pvalue=0.2875942425302301, df=4)
#
# Channel: F7-A1A2
# Wilcoxon
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
# Paired T-test
# ...

# %%
List_A16= [A_delta_16, A_theta_16, A_alpha_16, A_beta_16]

title= ['Delta', 'Theta', 'Alpha', 'Beta']

print('A面膜 第一次前和第二次後')
P_value(List_A16)
# Out:
# A面膜 第一次前和第二次後
# Delta
# Wilcoxon: p-value 小於 0.1
# ['F8-A1A2']
# Paired T test: p-value 小於 0.1
# ['F8-A1A2']
#
# Theta
# Wilcoxon: p-value 小於 0.1
# ['F8-A1A2']
#
# Alpha
# Wilcoxon: p-value 小於 0.1
# ['Pz-A1A2' 'F8-A1A2']
# Paired T test: p-value 小於 0.1
# ['Pz-A1A2' 'C4-A1A2' 'F8-A1A2']
#
# Beta

# %%
List_C16= [C_delta_16, C_theta_16, C_alpha_16, C_beta_16]

title= ['Delta', 'Theta', 'Alpha', 'Beta']

print('C面膜 第一次前和第二次後')
P_value(List_C16)
# Out:
# C面膜 第一次前和第二次後
# Delta
# Wilcoxon: p-value 小於 0.1
# ['F7-A1A2' 'T5-A1A2' 'Pz-A1A2' 'O2-A1A2']
# Paired T test: p-value 小於 0.1
# ['T5-A1A2' 'Pz-A1A2' 'P4-A1A2' 'O2-A1A2']
#
# Theta
# Paired T test: p-value 小於 0.1
# ['T3-A1A2']
#
# Alpha
# Paired T test: p-value 小於 0.1
# ['C4-A1A2']
#
# Beta
# Wilcoxon: p-value 小於 0.1
# ['C3-A1A2' 'C4-A1A2']
