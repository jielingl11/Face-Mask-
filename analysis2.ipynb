# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
def read_file(file):
    data= np.loadtxt('QEEG_data/'+file+'.csv', skiprows=1, delimiter=',', unpack= True, usecols=(1,2,3,4))
    return data

# %%
channel= np.loadtxt('QEEG_data/A1/A11.csv', skiprows=1, delimiter=',', unpack= True, usecols=(0), dtype= 'str')

# %%
# no: 第幾次做的EEG
# cha：頻道
# fre: 頻率的index
def ch_data(chan, freq, no, mask):
    ch= np.array([])
    for i in range(1,6):
        filepath= str(mask)+str(i)+'/'+str(mask)+str(i)+str(no)
        A_ch1= read_file(filepath)[freq][chan]
        ch= np.append(ch, A_ch1)
    return ch

print('第一次')

def Wilcoxon_ch(freq, no1, no2, mask):
    for i in range(0, 19):
        print('Channel:', channel[i])
        A_0to4_ch1_1= ch_data(i,freq,no1, mask)
        A_0to4_ch1_2= ch_data(i,freq,no2, mask)
        print(stats.wilcoxon(A_0to4_ch1_1, A_0to4_ch1_2))
        print('')
        
print('面膜A 前和中比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 1, 2, 'A')
print('')

        
print('面膜A 前和中比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 1, 2, 'A')


print('面膜A 前和中比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 1, 2, 'A')


print('面膜A 前和中比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 1, 2, 'A')
# Out:
# 第一次
# 面膜A 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.27332167829229814)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: C4-A1A2
# ...

# %%
print('面膜A 中和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 2, 3, 'A')
print('')

        
print('面膜A 中和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 2, 3, 'A')


print('面膜A 中和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 2, 3, 'A')


print('面膜A 中和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 2, 3, 'A')
# Out:
# 面膜A 中和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=4.5, pvalue=0.4375)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=4.5, pvalue=0.8539232992870668)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.27332167829229814)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: C4-A1A2
# ...

# %%
print('面膜A 前和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 1, 3, 'A')
print('')

        
print('面膜A 前和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 1, 3, 'A')


print('面膜A 前和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 1, 3, 'A')


print('面膜A 前和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 1, 3, 'A')
# Out:
# 面膜A 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: C4-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# ...

# %%
print('面膜C 前和中比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 1, 2, 'C')
print('')

        
print('面膜C 前和中比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 1, 2, 'C')


print('面膜C 前和中比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 1, 2, 'C')


print('面膜C 前和中比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 1, 2, 'C')
# Out:
# 面膜C 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=1.0)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.27332167829229814)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: C4-A1A2
# ...

# %%
print('面膜C 中和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 2, 3, 'C')
print('')

        
print('面膜C 中和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 2, 3, 'C')


print('面膜C 中和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 2, 3, 'C')


print('面膜C 中和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 2, 3, 'C')
# Out:
# 面膜C 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=2.5, pvalue=0.1875)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: C4-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# ...

# %%
print('面膜C 前和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 1, 3, 'C')
print('')

        
print('面膜C 前和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 1, 3, 'C')


print('面膜C 前和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 1, 3, 'C')


print('面膜C 前和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 1, 3, 'C')
# Out:
# 面膜C 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: C4-A1A2
# ...

# %%
print('第二次')
print('')
print('面膜A 前和中比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 4, 5, 'A')
print('')

        
print('面膜A 前和中比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 4, 5, 'A')


print('面膜A 前和中比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 4, 5, 'A')


print('面膜A 前和中比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 4, 5, 'A')
# Out:
# 第二次
#
# 面膜A 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=3.5, pvalue=0.4375)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: C4-A1A2
# ...

# %%
print('面膜A 中和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 5, 6, 'A')
print('')

        
print('面膜A 中和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 5, 6, 'A')


print('面膜A 中和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 5, 6, 'A')


print('面膜A 中和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 5, 6, 'A')
# Out:
# 面膜A 中和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=3.5, pvalue=0.4375)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: C4-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# ...

# %%
print('面膜A 前和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 1, 3, 'A')
print('')

        
print('面膜A 前和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 1, 3, 'A')


print('面膜A 前和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 1, 3, 'A')


print('面膜A 前和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 1, 3, 'A')
# Out:
# 面膜A 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: C4-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# ...

# %%
print('面膜A 前和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 4, 6, 'A')
print('')

        
print('面膜A 前和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 4, 6, 'A')


print('面膜A 前和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 4, 6, 'A')


print('面膜A 前和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 4, 6, 'A')
# Out:
# 面膜A 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.27332167829229814)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# ...

# %%
print('面膜C 前和中比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 4, 5, 'C')
print('')

        
print('面膜C 前和中比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 4, 5, 'C')


print('面膜C 前和中比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 4, 5, 'C')


print('面膜C 前和中比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 4, 5, 'C')
# Out:
# 面膜C 前和中比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=3.5, pvalue=0.4375)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=5.5, pvalue=0.8125)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.0625)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.5929800980174267)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.1875)
#
# Channel: C4-A1A2
# ...

# %%
print('面膜C 中和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 5, 6, 'C')
print('')

        
print('面膜C 中和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 5, 6, 'C')


print('面膜C 中和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 5, 6, 'C')


print('面膜C 中和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 5, 6, 'C')
# Out:
# 面膜C 中和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=0.0, pvalue=0.10880943004054568)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=2.0, pvalue=0.5929800980174267)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=4.5, pvalue=0.625)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.125)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.7150006546880893)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=6.5, pvalue=0.8125)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=1.5, pvalue=0.1974660733580187)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=7.0, pvalue=1.0)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=6.0, pvalue=0.8125)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=7.5, pvalue=1.0)
#
# ...

# %%
print('面膜C 前和後比較')
print('Frequency: 0-4 Hz')
print('')
Wilcoxon_ch(0, 4, 6, 'C')
print('')

        
print('面膜C 前和後比較')
print('Frequency: 4-8 Hz')
print('')
Wilcoxon_ch(1, 4, 6, 'C')


print('面膜C 前和後比較')
print('Frequency: 8-13 Hz')
print('')
Wilcoxon_ch(2, 4, 6, 'C')


print('面膜C 前和後比較')
print('Frequency: 13-30 Hz')
print('')
Wilcoxon_ch(3, 4, 6, 'C')
# Out:
# 面膜C 前和後比較
# Frequency: 0-4 Hz
#
# Channel: Fp1-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: F3-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: C3-A1A2
# WilcoxonResult(statistic=2.5, pvalue=0.3572725590318747)
#
# Channel: P3-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: O1-A1A2
# WilcoxonResult(statistic=4.5, pvalue=0.625)
#
# Channel: F7-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: T3-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
#
# Channel: T5-A1A2
# WilcoxonResult(statistic=5.5, pvalue=0.625)
#
# Channel: Fz-A1A2
# WilcoxonResult(statistic=5.0, pvalue=0.625)
#
# Channel: Cz-A1A2
# WilcoxonResult(statistic=3.0, pvalue=0.3125)
#
# Channel: Pz-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.14412703481601533)
#
# Channel: Fp2-A1A2
# WilcoxonResult(statistic=4.0, pvalue=0.4375)
#
# Channel: F4-A1A2
# WilcoxonResult(statistic=1.0, pvalue=0.14412703481601533)
#
# Channel: C4-A1A2
# ...
